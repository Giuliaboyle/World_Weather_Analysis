# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 757

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tasiilaq
# Processing Record 2 of Set 1 | dharchula
# Processing Record 3 of Set 1 | naze
# Processing Record 4 of Set 1 | clyde river
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | kaitangata
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | pisco
# Processing Record 15 of Set 1 | vega de alatorre
# Processing Record 16 of Set 1 | skaelskor
# Processing Record 17 of Set 1 | ashington
# Processing Record 18 of Set 1 | plettenberg bay
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | luderitz
# Processing Record 23 of Set 1 | nome
# Processing Record 24 of Set 1 | saint george
# Processing Record 25 of Set 1 | taitung
# Processing Record 26 of Set 1 | bowen
# Processing Record 27 of Set 1 | taltal
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | reconquista
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | mount gambier
# Processing Record 34 of Set 1 | jamestown
# Processing Record 35 of Set 1 | aklavik
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | severo-kurilsk
# Processing Record 41 of Set 1 | sovetskiy
# Processing Record 42 of Set 1 | aasiaat
# Processing Record 43 of Set 1 | tuktoyaktuk
# Processing Record 44 of Set 1 | tonj
# Processing Record 45 of Set 1 | camamu
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | san policarpo
# Processing Record 48 of Set 1 | kruisfontein
# Processing Record 49 of Set 1 | rizhao
# Processing Record 50 of Set 1 | touros
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | totness
# Processing Record 3 of Set 2 | barrow
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | diamantina
# Processing Record 6 of Set 2 | vila velha
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | hirara
# Processing Record 9 of Set 2 | pangnirtung
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | ancud
# Processing Record 12 of Set 2 | waingapu
# Processing Record 13 of Set 2 | catabola
# Processing Record 14 of Set 2 | kyzyl-suu
# Processing Record 15 of Set 2 | shingu
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | caravelas
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | komsomolskiy
# Processing Record 20 of Set 2 | vila franca do campo
# Processing Record 21 of Set 2 | flin flon
# Processing Record 22 of Set 2 | lebu
# Processing Record 23 of Set 2 | leopold
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | los llanos de aridane
# Processing Record 27 of Set 2 | sambava
# Processing Record 28 of Set 2 | kulhudhuffushi
# Processing Record 29 of Set 2 | krasnoborsk
# Processing Record 30 of Set 2 | dzaoudzi
# Processing Record 31 of Set 2 | sapouy
# Processing Record 32 of Set 2 | hope
# Processing Record 33 of Set 2 | leningradskiy
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 2 | paradwip
# City not found. Skipping...
# Processing Record 37 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 38 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 2 | castro
# Processing Record 40 of Set 2 | hofn
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | takoradi
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | santa rosa
# Processing Record 45 of Set 2 | dandong
# Processing Record 46 of Set 2 | wakuya
# Processing Record 47 of Set 2 | amahai
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 2 | christchurch
# Processing Record 1 of Set 3 | bonavista
# Processing Record 2 of Set 3 | guiratinga
# Processing Record 3 of Set 3 | baruun-urt
# Processing Record 4 of Set 3 | lavrentiya
# Processing Record 5 of Set 3 | moerai
# Processing Record 6 of Set 3 | husavik
# Processing Record 7 of Set 3 | langres
# Processing Record 8 of Set 3 | laguna
# Processing Record 9 of Set 3 | tiksi
# Processing Record 10 of Set 3 | zlobin
# Processing Record 11 of Set 3 | cidreira
# Processing Record 12 of Set 3 | half moon bay
# Processing Record 13 of Set 3 | zhigansk
# Processing Record 14 of Set 3 | gat
# Processing Record 15 of Set 3 | tazovskiy
# Processing Record 16 of Set 3 | bani walid
# Processing Record 17 of Set 3 | sept-iles
# Processing Record 18 of Set 3 | okhotsk
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | svetlogorsk
# Processing Record 21 of Set 3 | maragogi
# Processing Record 22 of Set 3 | general pico
# Processing Record 23 of Set 3 | canyon
# Processing Record 24 of Set 3 | ostrovnoy
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | deputatskiy
# Processing Record 27 of Set 3 | det udom
# Processing Record 28 of Set 3 | mao
# Processing Record 29 of Set 3 | ritchie
# Processing Record 30 of Set 3 | marau
# Processing Record 31 of Set 3 | saint-pierre
# Processing Record 32 of Set 3 | borogontsy
# Processing Record 33 of Set 3 | beyneu
# Processing Record 34 of Set 3 | hargeysa
# Processing Record 35 of Set 3 | ormara
# Processing Record 36 of Set 3 | mahebourg
# Processing Record 37 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 3 | hambantota
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | manoel urbano
# Processing Record 41 of Set 3 | ponta do sol
# Processing Record 42 of Set 3 | lorengau
# Processing Record 43 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | moron
# Processing Record 46 of Set 3 | isangel
# Processing Record 47 of Set 3 | kultuk
# Processing Record 48 of Set 3 | dikson
# Processing Record 49 of Set 3 | ajdabiya
# Processing Record 50 of Set 3 | uyuni
# Processing Record 1 of Set 4 | yar-sale
# Processing Record 2 of Set 4 | nabire
# Processing Record 3 of Set 4 | vicuna
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | coquimbo
# Processing Record 6 of Set 4 | port macquarie
# Processing Record 7 of Set 4 | we
# City not found. Skipping...
# Processing Record 8 of Set 4 | codrington
# Processing Record 9 of Set 4 | port lincoln
# Processing Record 10 of Set 4 | saldanha
# Processing Record 11 of Set 4 | filingue
# Processing Record 12 of Set 4 | marica
# Processing Record 13 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 4 | vaini
# Processing Record 15 of Set 4 | bassano
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | port alfred
# Processing Record 18 of Set 4 | avera
# Processing Record 19 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 4 | grand island
# Processing Record 21 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 4 | avarua
# Processing Record 23 of Set 4 | price
# Processing Record 24 of Set 4 | geraldton
# Processing Record 25 of Set 4 | north bend
# Processing Record 26 of Set 4 | dillon
# Processing Record 27 of Set 4 | grindavik
# Processing Record 28 of Set 4 | kambove
# Processing Record 29 of Set 4 | hvammstangi
# City not found. Skipping...
# Processing Record 30 of Set 4 | roald
# Processing Record 31 of Set 4 | kaduqli
# Processing Record 32 of Set 4 | maumere
# Processing Record 33 of Set 4 | chilca
# Processing Record 34 of Set 4 | natal
# Processing Record 35 of Set 4 | zhangye
# Processing Record 36 of Set 4 | mangit
# Processing Record 37 of Set 4 | perevolotskiy
# Processing Record 38 of Set 4 | mitchell
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | lagoa
# Processing Record 41 of Set 4 | la ronge
# Processing Record 42 of Set 4 | ilulissat
# Processing Record 43 of Set 4 | nikolskoye
# Processing Record 44 of Set 4 | mitu
# Processing Record 45 of Set 4 | zuwarah
# Processing Record 46 of Set 4 | dali
# Processing Record 47 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 4 | souillac
# Processing Record 49 of Set 4 | honningsvag
# Processing Record 50 of Set 4 | chiguayante
# Processing Record 1 of Set 5 | alexandria
# Processing Record 2 of Set 5 | zapolyarnyy
# Processing Record 3 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 5 | waddan
# Processing Record 5 of Set 5 | mizque
# Processing Record 6 of Set 5 | kumluca
# Processing Record 7 of Set 5 | krabi
# Processing Record 8 of Set 5 | bethel
# Processing Record 9 of Set 5 | henties bay
# Processing Record 10 of Set 5 | ondorhaan
# City not found. Skipping...
# Processing Record 11 of Set 5 | kavaratti
# Processing Record 12 of Set 5 | charters towers
# Processing Record 13 of Set 5 | kavieng
# Processing Record 14 of Set 5 | iqaluit
# Processing Record 15 of Set 5 | yanam
# Processing Record 16 of Set 5 | agadez
# Processing Record 17 of Set 5 | sao joao da barra
# Processing Record 18 of Set 5 | zelenoborskiy
# Processing Record 19 of Set 5 | aykhal
# Processing Record 20 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 5 | kodiak
# Processing Record 22 of Set 5 | pinheiro machado
# Processing Record 23 of Set 5 | grand forks
# Processing Record 24 of Set 5 | puerto ayora
# Processing Record 25 of Set 5 | lingao
# Processing Record 26 of Set 5 | gumdag
# Processing Record 27 of Set 5 | lubao
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | garowe
# Processing Record 30 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 5 | lompoc
# Processing Record 32 of Set 5 | obo
# Processing Record 33 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 5 | yellowknife
# Processing Record 35 of Set 5 | sarangani
# Processing Record 36 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 5 | newport
# Processing Record 38 of Set 5 | maldonado
# Processing Record 39 of Set 5 | chuy
# Processing Record 40 of Set 5 | ossora
# Processing Record 41 of Set 5 | sarkand
# Processing Record 42 of Set 5 | sorland
# Processing Record 43 of Set 5 | makhachkala
# Processing Record 44 of Set 5 | camacha
# Processing Record 45 of Set 5 | bengkulu
# Processing Record 46 of Set 5 | taoudenni
# Processing Record 47 of Set 5 | verkhnyaya inta
# Processing Record 48 of Set 5 | chokurdakh
# Processing Record 49 of Set 5 | mayo
# Processing Record 50 of Set 5 | deming
# Processing Record 1 of Set 6 | cherskiy
# Processing Record 2 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 6 | kinshasa
# Processing Record 4 of Set 6 | katobu
# Processing Record 5 of Set 6 | alice springs
# Processing Record 6 of Set 6 | teahupoo
# Processing Record 7 of Set 6 | san quintin
# Processing Record 8 of Set 6 | leh
# Processing Record 9 of Set 6 | hay river
# Processing Record 10 of Set 6 | flinders
# Processing Record 11 of Set 6 | arraial do cabo
# Processing Record 12 of Set 6 | moses lake
# Processing Record 13 of Set 6 | manaus
# Processing Record 14 of Set 6 | georgetown
# Processing Record 15 of Set 6 | eyl
# Processing Record 16 of Set 6 | yichang
# Processing Record 17 of Set 6 | perehonivka
# Processing Record 18 of Set 6 | bandarbeyla
# Processing Record 19 of Set 6 | vestmannaeyjar
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | komlo
# Processing Record 22 of Set 6 | bocaiuva
# Processing Record 23 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 24 of Set 6 | mamallapuram
# Processing Record 25 of Set 6 | strezhevoy
# Processing Record 26 of Set 6 | chon daen
# Processing Record 27 of Set 6 | kismayo
# Processing Record 28 of Set 6 | nantucket
# Processing Record 29 of Set 6 | laurel
# Processing Record 30 of Set 6 | qostanay
# Processing Record 31 of Set 6 | rabo de peixe
# Processing Record 32 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 33 of Set 6 | tamala
# Processing Record 34 of Set 6 | mar del plata
# Processing Record 35 of Set 6 | latung
# Processing Record 36 of Set 6 | itoman
# Processing Record 37 of Set 6 | djibo
# Processing Record 38 of Set 6 | havoysund
# Processing Record 39 of Set 6 | narsaq
# Processing Record 40 of Set 6 | andenes
# Processing Record 41 of Set 6 | ahipara
# Processing Record 42 of Set 6 | santa cruz de la palma
# Processing Record 43 of Set 6 | tarko-sale
# Processing Record 44 of Set 6 | altay
# Processing Record 45 of Set 6 | zvishavane
# Processing Record 46 of Set 6 | talnakh
# Processing Record 47 of Set 6 | vao
# Processing Record 48 of Set 6 | port hawkesbury
# Processing Record 49 of Set 6 | nhulunbuy
# Processing Record 50 of Set 6 | vardo
# Processing Record 1 of Set 7 | ahuimanu
# Processing Record 2 of Set 7 | samarai
# Processing Record 3 of Set 7 | lazaro cardenas
# Processing Record 4 of Set 7 | imbituba
# Processing Record 5 of Set 7 | kamaishi
# Processing Record 6 of Set 7 | dingle
# Processing Record 7 of Set 7 | zyryanka
# Processing Record 8 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 7 | qaanaaq
# Processing Record 10 of Set 7 | lupiro
# Processing Record 11 of Set 7 | troitskoye
# Processing Record 12 of Set 7 | othonoi
# City not found. Skipping...
# Processing Record 13 of Set 7 | gizo
# Processing Record 14 of Set 7 | khrebtovaya
# Processing Record 15 of Set 7 | nanortalik
# Processing Record 16 of Set 7 | sedniv
# Processing Record 17 of Set 7 | bababe
# City not found. Skipping...
# Processing Record 18 of Set 7 | villefranche-sur-saone
# Processing Record 19 of Set 7 | belmopan
# Processing Record 20 of Set 7 | erzin
# Processing Record 21 of Set 7 | haukipudas
# Processing Record 22 of Set 7 | pyaozerskiy
# Processing Record 23 of Set 7 | san jeronimo
# Processing Record 24 of Set 7 | beira
# Processing Record 25 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 26 of Set 7 | port keats
# Processing Record 27 of Set 7 | hovd
# Processing Record 28 of Set 7 | luanda
# Processing Record 29 of Set 7 | terrace
# Processing Record 30 of Set 7 | dubai
# Processing Record 31 of Set 7 | morgan city
# Processing Record 32 of Set 7 | cap malheureux
# Processing Record 33 of Set 7 | ullapool
# Processing Record 34 of Set 7 | methoni
# Processing Record 35 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 7 | torbay
# Processing Record 37 of Set 7 | toora-khem
# Processing Record 38 of Set 7 | bonthe
# Processing Record 39 of Set 7 | clocolan
# Processing Record 40 of Set 7 | marawi
# Processing Record 41 of Set 7 | gravdal
# Processing Record 42 of Set 7 | kitgum
# Processing Record 43 of Set 7 | bambous virieux
# Processing Record 44 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 45 of Set 7 | hokitika
# Processing Record 46 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 47 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 48 of Set 7 | faya
# Processing Record 49 of Set 7 | bilibino
# Processing Record 50 of Set 7 | tahta
# Processing Record 1 of Set 8 | brae
# Processing Record 2 of Set 8 | ciras
# City not found. Skipping...
# Processing Record 3 of Set 8 | pochutla
# Processing Record 4 of Set 8 | namibe
# Processing Record 5 of Set 8 | tilichiki
# Processing Record 6 of Set 8 | cururupu
# Processing Record 7 of Set 8 | xingyi
# Processing Record 8 of Set 8 | bontang
# Processing Record 9 of Set 8 | skibbereen
# Processing Record 10 of Set 8 | tongren
# Processing Record 11 of Set 8 | chapais
# Processing Record 12 of Set 8 | moussoro
# Processing Record 13 of Set 8 | storforshei
# Processing Record 14 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 8 | megion
# Processing Record 16 of Set 8 | yeppoon
# Processing Record 17 of Set 8 | davidson
# Processing Record 18 of Set 8 | gobo
# Processing Record 19 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 8 | hvide sande
# Processing Record 21 of Set 8 | bongor
# Processing Record 22 of Set 8 | olafsvik
# Processing Record 23 of Set 8 | omsukchan
# Processing Record 24 of Set 8 | hualmay
# Processing Record 25 of Set 8 | grand gaube
# Processing Record 26 of Set 8 | puerto del rosario
# Processing Record 27 of Set 8 | nago
# Processing Record 28 of Set 8 | cabedelo
# Processing Record 29 of Set 8 | aberdeen
# Processing Record 30 of Set 8 | longyearbyen
# Processing Record 31 of Set 8 | jiwani
# Processing Record 32 of Set 8 | chunoyar
# Processing Record 33 of Set 8 | walvis bay
# Processing Record 34 of Set 8 | beringovskiy
# Processing Record 35 of Set 8 | havre-saint-pierre
# Processing Record 36 of Set 8 | wodonga
# Processing Record 37 of Set 8 | araguacu
# Processing Record 38 of Set 8 | annoeullin
# Processing Record 39 of Set 8 | springdale
# Processing Record 40 of Set 8 | santa rita
# Processing Record 41 of Set 8 | waipawa
# Processing Record 42 of Set 8 | bustamante
# Processing Record 43 of Set 8 | tornio
# Processing Record 44 of Set 8 | manokwari
# Processing Record 45 of Set 8 | karangasem
# Processing Record 46 of Set 8 | guerrero negro
# Processing Record 47 of Set 8 | poya
# Processing Record 48 of Set 8 | sola
# Processing Record 49 of Set 8 | orlik
# Processing Record 50 of Set 8 | mutata
# Processing Record 1 of Set 9 | puerto penasco
# Processing Record 2 of Set 9 | kaeo
# Processing Record 3 of Set 9 | constitucion
# Processing Record 4 of Set 9 | dauphin
# Processing Record 5 of Set 9 | arlit
# Processing Record 6 of Set 9 | rundu
# Processing Record 7 of Set 9 | parrita
# Processing Record 8 of Set 9 | huautla
# Processing Record 9 of Set 9 | kaspican
# City not found. Skipping...
# Processing Record 10 of Set 9 | fort nelson
# Processing Record 11 of Set 9 | verkhoyansk
# Processing Record 12 of Set 9 | podporozhye
# Processing Record 13 of Set 9 | brus laguna
# Processing Record 14 of Set 9 | port augusta
# Processing Record 15 of Set 9 | aksu
# Processing Record 16 of Set 9 | sao felix do xingu
# Processing Record 17 of Set 9 | ventspils
# Processing Record 18 of Set 9 | agucadoura
# Processing Record 19 of Set 9 | tuy hoa
# Processing Record 20 of Set 9 | yurgamysh
# Processing Record 21 of Set 9 | panormos
# Processing Record 22 of Set 9 | adrar
# Processing Record 23 of Set 9 | monrovia
# Processing Record 24 of Set 9 | male
# Processing Record 25 of Set 9 | hun
# Processing Record 26 of Set 9 | pitimbu
# Processing Record 27 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 28 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 9 | kungurtug
# Processing Record 30 of Set 9 | port-gentil
# Processing Record 31 of Set 9 | mehamn
# Processing Record 32 of Set 9 | rosarito
# Processing Record 33 of Set 9 | barinas
# Processing Record 34 of Set 9 | sangar
# Processing Record 35 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 9 | sampit
# Processing Record 37 of Set 9 | nishihara
# Processing Record 38 of Set 9 | kostino
# Processing Record 39 of Set 9 | gornopravdinsk
# Processing Record 40 of Set 9 | qaqortoq
# Processing Record 41 of Set 9 | lakselv
# Processing Record 42 of Set 9 | pasco
# Processing Record 43 of Set 9 | santiago del estero
# Processing Record 44 of Set 9 | sinnamary
# Processing Record 45 of Set 9 | ribeira grande
# Processing Record 46 of Set 9 | baiyin
# Processing Record 47 of Set 9 | pastavy
# Processing Record 48 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 9 | arman
# Processing Record 50 of Set 9 | tessalit
# Processing Record 1 of Set 10 | nizhnyaya tavda
# Processing Record 2 of Set 10 | itanagar
# Processing Record 3 of Set 10 | praia da vitoria
# Processing Record 4 of Set 10 | thanatpin
# Processing Record 5 of Set 10 | muzaffarabad
# Processing Record 6 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 10 | sovetskaya gavan
# Processing Record 8 of Set 10 | ishigaki
# Processing Record 9 of Set 10 | mitsamiouli
# Processing Record 10 of Set 10 | srednekolymsk
# Processing Record 11 of Set 10 | kununurra
# Processing Record 12 of Set 10 | tutoia
# Processing Record 13 of Set 10 | wellington
# Processing Record 14 of Set 10 | da nang
# Processing Record 15 of Set 10 | lagos
# Processing Record 16 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 10 | itaituba
# Processing Record 18 of Set 10 | paamiut
# Processing Record 19 of Set 10 | kabompo
# Processing Record 20 of Set 10 | kampot
# Processing Record 21 of Set 10 | mangan
# Processing Record 22 of Set 10 | camopi
# Processing Record 23 of Set 10 | egvekinot
# Processing Record 24 of Set 10 | darlawn
# Processing Record 25 of Set 10 | alpena
# Processing Record 26 of Set 10 | menongue
# Processing Record 27 of Set 10 | zheleznodorozhnyy
# Processing Record 28 of Set 10 | khanpur
# Processing Record 29 of Set 10 | bubaque
# Processing Record 30 of Set 10 | bouar
# Processing Record 31 of Set 10 | great yarmouth
# Processing Record 32 of Set 10 | humberto de campos
# Processing Record 33 of Set 10 | kaspiysk
# Processing Record 34 of Set 10 | asbe teferi
# Processing Record 35 of Set 10 | seoul
# Processing Record 36 of Set 10 | krasnogorsk
# Processing Record 37 of Set 10 | ocu
# Processing Record 38 of Set 10 | ayacucho
# Processing Record 39 of Set 10 | rupert
# Processing Record 40 of Set 10 | dunedin
# Processing Record 41 of Set 10 | the valley
# Processing Record 42 of Set 10 | vavuniya
# Processing Record 43 of Set 10 | falun
# Processing Record 44 of Set 10 | ca mau
# Processing Record 45 of Set 10 | lisakovsk
# Processing Record 46 of Set 10 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 47 of Set 10 | baykit
# Processing Record 48 of Set 10 | sungai siput utara
# City not found. Skipping...
# Processing Record 49 of Set 10 | kieta
# Processing Record 50 of Set 10 | kastamonu
# Processing Record 1 of Set 11 | odweyne
# Processing Record 2 of Set 11 | amli
# Processing Record 3 of Set 11 | berlevag
# Processing Record 4 of Set 11 | veraval
# Processing Record 5 of Set 11 | linjiang
# Processing Record 6 of Set 11 | nouakchott
# Processing Record 7 of Set 11 | bintulu
# Processing Record 8 of Set 11 | marsh harbour
# Processing Record 9 of Set 11 | sulangan
# Processing Record 10 of Set 11 | cherlak
# Processing Record 11 of Set 11 | ambunti
# Processing Record 12 of Set 11 | ondjiva
# Processing Record 13 of Set 11 | thinadhoo
# Processing Record 14 of Set 11 | estelle
# Processing Record 15 of Set 11 | katsuura
# Processing Record 16 of Set 11 | asau
# Processing Record 17 of Set 11 | am timan
# Processing Record 18 of Set 11 | kargasok
# Processing Record 19 of Set 11 | benguela
# Processing Record 20 of Set 11 | adwa
# Processing Record 21 of Set 11 | high rock
# Processing Record 22 of Set 11 | udaipur
# Processing Record 23 of Set 11 | vanimo
# Processing Record 24 of Set 11 | diamantino
# Processing Record 25 of Set 11 | bundaberg
# Processing Record 26 of Set 11 | dawlatabad
# Processing Record 27 of Set 11 | atarfe
# Processing Record 28 of Set 11 | coolum beach
# Processing Record 29 of Set 11 | marechal candido rondon
# Processing Record 30 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 11 | gashua
# Processing Record 32 of Set 11 | domoni
# Processing Record 33 of Set 11 | sabang
# Processing Record 34 of Set 11 | zhoucheng
# Processing Record 35 of Set 11 | borba
# Processing Record 36 of Set 11 | crossville
# Processing Record 37 of Set 11 | atlantic beach
# Processing Record 38 of Set 11 | malmesbury
# Processing Record 39 of Set 11 | teacapan
# Processing Record 40 of Set 11 | molokovo
# Processing Record 41 of Set 11 | czluchow
# Processing Record 42 of Set 11 | santa isabel
# Processing Record 43 of Set 11 | kenora
# Processing Record 44 of Set 11 | muros
# Processing Record 45 of Set 11 | hamilton
# Processing Record 46 of Set 11 | port hardy
# Processing Record 47 of Set 11 | kutum
# Processing Record 48 of Set 11 | ginir
# Processing Record 49 of Set 11 | boyolangu
# Processing Record 50 of Set 11 | anadyr
# Processing Record 1 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 2 of Set 12 | sokolo
# Processing Record 3 of Set 12 | cabo rojo
# Processing Record 4 of Set 12 | atar
# Processing Record 5 of Set 12 | gambo
# Processing Record 6 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 8 of Set 12 | mareeba
# Processing Record 9 of Set 12 | bangassou
# Processing Record 10 of Set 12 | alofi
# Processing Record 11 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 12 | lola
# Processing Record 13 of Set 12 | prainha
# Processing Record 14 of Set 12 | la palma
# Processing Record 15 of Set 12 | scarborough
# Processing Record 16 of Set 12 | dargaville
# Processing Record 17 of Set 12 | igarka
# Processing Record 18 of Set 12 | carutapera
# Processing Record 19 of Set 12 | biltine
# Processing Record 20 of Set 12 | springbok
# Processing Record 21 of Set 12 | sao miguel do araguaia
# Processing Record 22 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 12 | acarau
# Processing Record 24 of Set 12 | iskateley
# Processing Record 25 of Set 12 | tual
# Processing Record 26 of Set 12 | anshun
# Processing Record 27 of Set 12 | chicama
# Processing Record 28 of Set 12 | yulara
# Processing Record 29 of Set 12 | linhares
# Processing Record 30 of Set 12 | chulman
# Processing Record 31 of Set 12 | new bern
# Processing Record 32 of Set 12 | makakilo city
# Processing Record 33 of Set 12 | warrnambool
# Processing Record 34 of Set 12 | talaya
# Processing Record 35 of Set 12 | mhango
# Processing Record 36 of Set 12 | aswan
# Processing Record 37 of Set 12 | coihaique
# Processing Record 38 of Set 12 | ambovombe
# Processing Record 39 of Set 12 | sitka
# Processing Record 40 of Set 12 | bom jardim
# Processing Record 41 of Set 12 | margate
# Processing Record 42 of Set 12 | xining
# Processing Record 43 of Set 12 | taksimo
# Processing Record 44 of Set 12 | sao filipe
# Processing Record 45 of Set 12 | riyadh
# Processing Record 46 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 48 of Set 12 | portland
# Processing Record 49 of Set 12 | quelimane
# Processing Record 50 of Set 12 | patacamaya
# Processing Record 1 of Set 13 | sakakah
# Processing Record 2 of Set 13 | lanzhou
# Processing Record 3 of Set 13 | les escoumins
# Processing Record 4 of Set 13 | jalu
# Processing Record 5 of Set 13 | kokopo
# Processing Record 6 of Set 13 | khandyga
# Processing Record 7 of Set 13 | tommot
# Processing Record 8 of Set 13 | nakusp
# Processing Record 9 of Set 13 | ermoupolis
# Processing Record 10 of Set 13 | san cristobal
# Processing Record 11 of Set 13 | olinda
# Processing Record 12 of Set 13 | vagur
# Processing Record 13 of Set 13 | santa vitoria do palmar
# Processing Record 14 of Set 13 | belaya gora
# Processing Record 15 of Set 13 | tapaua
# City not found. Skipping...
# Processing Record 16 of Set 13 | florianopolis
# Processing Record 17 of Set 13 | tongzi
# Processing Record 18 of Set 13 | bhadasar
# Processing Record 19 of Set 13 | san patricio
# Processing Record 20 of Set 13 | harlingen
# Processing Record 21 of Set 13 | rawson
# Processing Record 22 of Set 13 | murindo
# Processing Record 23 of Set 13 | lethem
# Processing Record 24 of Set 13 | manzanillo
# Processing Record 25 of Set 13 | lashio
# Processing Record 26 of Set 13 | baturaja
# Processing Record 27 of Set 13 | seda
# Processing Record 28 of Set 13 | maceio
# Processing Record 29 of Set 13 | miechow
# Processing Record 30 of Set 13 | bodden town
# Processing Record 31 of Set 13 | uthal
# Processing Record 32 of Set 13 | hailey
# Processing Record 33 of Set 13 | manica
# Processing Record 34 of Set 13 | benjamin constant
# Processing Record 35 of Set 13 | lensk
# Processing Record 36 of Set 13 | buala
# Processing Record 37 of Set 13 | swan hill
# Processing Record 38 of Set 13 | vinh
# Processing Record 39 of Set 13 | dourbali
# Processing Record 40 of Set 13 | ntoum
# Processing Record 41 of Set 13 | lucapa
# Processing Record 42 of Set 13 | sofiyivka
# Processing Record 43 of Set 13 | maniitsoq
# Processing Record 44 of Set 13 | svetlyy
# Processing Record 45 of Set 13 | ambulu
# Processing Record 46 of Set 13 | manzhouli
# Processing Record 47 of Set 13 | college
# Processing Record 48 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 49 of Set 13 | haifa
# Processing Record 50 of Set 13 | ifo
# Processing Record 1 of Set 14 | buckingham
# Processing Record 2 of Set 14 | mbandaka
# Processing Record 3 of Set 14 | bairiki
# Processing Record 4 of Set 14 | ust-nera
# Processing Record 5 of Set 14 | koyilandi
# City not found. Skipping...
# Processing Record 6 of Set 14 | mpigi
# Processing Record 7 of Set 14 | raymond
# Processing Record 8 of Set 14 | xacmaz
# Processing Record 9 of Set 14 | sale
# Processing Record 10 of Set 14 | altagracia de orituco
# Processing Record 11 of Set 14 | scharding
# Processing Record 12 of Set 14 | verkh-chebula
# Processing Record 13 of Set 14 | chiredzi
# Processing Record 14 of Set 14 | derzhavinsk
# Processing Record 15 of Set 14 | galle
# Processing Record 16 of Set 14 | amazar
# Processing Record 17 of Set 14 | kondoa
# Processing Record 18 of Set 14 | turayf
# Processing Record 19 of Set 14 | kangaatsiaq
# Processing Record 20 of Set 14 | tibati
# Processing Record 21 of Set 14 | santa marta
# Processing Record 22 of Set 14 | umm durman
# City not found. Skipping...
# Processing Record 23 of Set 14 | proddatur
# Processing Record 24 of Set 14 | yokadouma
# Processing Record 25 of Set 14 | pak phanang
# Processing Record 26 of Set 14 | vanavara
# Processing Record 27 of Set 14 | mount isa
# Processing Record 28 of Set 14 | sonoita
# Processing Record 29 of Set 14 | bra
# Processing Record 30 of Set 14 | ugoofaaru
# Processing Record 31 of Set 14 | kidal
# Processing Record 32 of Set 14 | bathsheba
# Processing Record 33 of Set 14 | vestmanna
# Processing Record 34 of Set 14 | puerto escondido
# Processing Record 35 of Set 14 | verkhnechusovskiye gorodki
# Processing Record 36 of Set 14 | alta floresta
# Processing Record 37 of Set 14 | hami
# Processing Record 38 of Set 14 | cravo norte
# Processing Record 39 of Set 14 | les cayes
# Processing Record 40 of Set 14 | coahuayana
# Processing Record 41 of Set 14 | herveo
# Processing Record 42 of Set 14 | wladyslawowo
# Processing Record 43 of Set 14 | dovers
# Processing Record 44 of Set 14 | ternate
# Processing Record 45 of Set 14 | elizabeth city
# Processing Record 46 of Set 14 | zharkent
# Processing Record 47 of Set 14 | siavonga
# Processing Record 48 of Set 14 | mana
# Processing Record 49 of Set 14 | esperance
# Processing Record 50 of Set 14 | talahiban
# City not found. Skipping...
# Processing Record 1 of Set 15 | teguise
# Processing Record 2 of Set 15 | pafos
# Processing Record 3 of Set 15 | tombouctou
# Processing Record 4 of Set 15 | san juan de uraba
# Processing Record 5 of Set 15 | tanout
# Processing Record 6 of Set 15 | kharan
# Processing Record 7 of Set 15 | moree
# Processing Record 8 of Set 15 | novikovo
# Processing Record 9 of Set 15 | tumut
# Processing Record 10 of Set 15 | lodeynoye pole
# Processing Record 11 of Set 15 | mata
# Processing Record 12 of Set 15 | rumoi
# Processing Record 13 of Set 15 | kihei
# Processing Record 14 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 15 of Set 15 | dwarka
# Processing Record 16 of Set 15 | vitez
# Processing Record 17 of Set 15 | nichinan
# Processing Record 18 of Set 15 | guaxupe
# Processing Record 19 of Set 15 | villa union
# Processing Record 20 of Set 15 | port alberni
# Processing Record 21 of Set 15 | mercedes
# Processing Record 22 of Set 15 | caledon east
# Processing Record 23 of Set 15 | meadow lake
# Processing Record 24 of Set 15 | rock sound
# Processing Record 25 of Set 15 | lubango
# Processing Record 26 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 15 | agirish
# Processing Record 28 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 15 | bulawayo
# Processing Record 30 of Set 15 | nicoya
# Processing Record 31 of Set 15 | puerto ayacucho
# Processing Record 32 of Set 15 | cockburn town
# Processing Record 33 of Set 15 | oktyabrskoye
# Processing Record 34 of Set 15 | dire
# Processing Record 35 of Set 15 | cozumel
# Processing Record 36 of Set 15 | antofagasta
# Processing Record 37 of Set 15 | kiunga
# Processing Record 38 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 39 of Set 15 | areosa
# Processing Record 40 of Set 15 | las margaritas
# Processing Record 41 of Set 15 | navoi
# Processing Record 42 of Set 15 | labuhan
# Processing Record 43 of Set 15 | chengde
# Processing Record 44 of Set 15 | lofthus
# Processing Record 45 of Set 15 | kyaikto
# Processing Record 46 of Set 15 | conceicao do araguaia
# Processing Record 47 of Set 15 | porto novo
# Processing Record 48 of Set 15 | szczytno
# Processing Record 49 of Set 15 | port blair
# Processing Record 50 of Set 15 | omutinskoye
# City not found. Skipping...
# Processing Record 1 of Set 16 | tagusao
# Processing Record 2 of Set 16 | tecpan
# Processing Record 3 of Set 16 | kurilsk
# Processing Record 4 of Set 16 | fort saint james
# Processing Record 5 of Set 16 | itarema
# Processing Record 6 of Set 16 | umm lajj
# Processing Record 7 of Set 16 | linxia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Tasiilaq      GL  65.6145  -37.6368     32.16        86          99
# 1    Dharchula      IN  29.8500   80.5333     62.15        26           4
# 2         Naze      JP  28.3667  129.4833     58.12        65          95
# 3  Clyde River      CA  70.4692  -68.5914     12.43        92          20
# 4        Kapaa      US  22.0752 -159.3190     73.47        84         100
# 5   Kaitangata      NZ -46.2817  169.8464     46.08        95          68
# 6      Rikitea      PF -23.1203 -134.9692     76.50        64          46
# 7    Cape Town      ZA -33.9258   18.4232     65.91        78          20
# 8       Albany      US  42.6001  -73.9662     44.02        78         100
# 9        Pisco      PE -13.7000  -76.2167     71.65        68           0
#
#    Wind Speed Current Description
# 0        2.64     overcast clouds
# 1        8.68           clear sky
# 2       11.95     overcast clouds
# 3        4.61          few clouds
# 4       19.57     overcast clouds
# 5        5.35       broken clouds
# 6        9.44    scattered clouds
# 7       12.66          few clouds
# 8        1.59          light rain
# 9        9.22           clear sky

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/rc/_9pnfwvn3kb9qz1n5wbmsv4c0000gn/T/ipykernel_87821/3782751744.py in <module>
#       1 output_data_file = "Weather_Database/WeatherPy_Database.csv"
# ----> 2 city_data_df.to_csv(output_data_file, index_label='City_ID')
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/formats/csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
